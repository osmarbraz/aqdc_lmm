# %% [markdown]
# # Experimento 1 / +T+R

# %%
from sklearn.metrics import cohen_kappa_score
import numpy as np

avaliador1 = [
    0, 20, 20, 40, 5, 5, 15, 25, 25, 40,
    0, 40, 0, 27, 38, 20, 10, 20, 30, 20,
    20, 40, 15, 40, 40, 20, 20, 35, 30, 20,
    10, 0, 40, 40, 40, 10, 0, 0, 15, 40,
    30, 25, 15, 30, 35, 10, 10, 30, 40, 20,
    27, 40, 25, 30, 0, 30, 40, 10, 10, 30,
    25, 40, 10, 0, 10, 20, 20, 5, 10, 20,
    0, 40, 40, 40, 0, 10, 30, 0, 30, 40,
    0.5, 40, 20, 0, 30, 40, 30, 10, 30, 12,
    20, 10, 35, 30, 20, 10, 20, 30, 40, 25,
    40, 10, 25, 35, 30, 10, 12, 25, 10, 30,
    20, 10, 40, 20, 20, 20, 25, 40, 40, 10,
    20, 10, 0, 25, 10, 40, 0, 20, 10
]
avaliador1 = [round(x) for x in avaliador1]
print(len(avaliador1))

avaliador2 = [
    0, 0, 15, 30, 10, 10, 15, 10, 25, 40,
    0, 40, 10, 25, 35, 20, 15, 0, 25, 10,
    20, 35, 20, 40, 40, 35, 25, 30, 35, 25,
    10, 0, 40, 40, 30, 10, 0, 0, 15, 40,
    20, 20, 30, 30, 35, 10, 15, 35, 35, 25,
    28, 40, 20, 30, 0, 30, 40, 10, 0, 30,
    20, 40, 25, 0, 10, 20, 30, 10, 20, 20,
    0, 40, 40, 40, 5, 10, 32, 0, 35, 40,
    0, 40, 30, 0, 30, 40, 30, 0, 30, 10,
    20, 10, 40, 30, 20, 7, 20, 40, 40, 27,
    35, 25, 25, 35, 35, 5, 10, 20, 20, 35,
    20, 10, 40, 20, 22, 20, 40, 40, 40, 0,
    30, 10, 0, 25, 10, 40, 0, 10, 10
]
avaliador2 = [round(x) for x in avaliador2]
print(len(avaliador2))

media = [
    0, 10, 17.5, 35, 7.5, 7.5, 15, 17.5, 25, 40,
    0, 40, 5, 26, 36.5, 20, 12.5, 10, 27.5, 15,
    20, 37.5, 17.5, 40, 40, 27.5, 22.5, 32.5, 32.5, 22.5,
    10, 0, 40, 40, 35, 10, 0, 0, 15, 40,
    25, 22.5, 22.5, 30, 35, 10, 12.5, 32.5, 37.5, 22.5,
    27.5, 40, 22.5, 30, 0, 30, 40, 10, 5, 30,
    22.5, 40, 17.5, 0, 10, 20, 25, 7.5, 15, 20,
    0, 40, 40, 40, 2.5, 10, 31, 0, 32.5, 40,
    0.25, 40, 25, 0, 30, 40, 30, 5, 30, 11,
    20, 10, 37.5, 30, 20, 8.5, 20, 35, 40, 26,
    37.5, 17.5, 25, 35, 32.5, 7.5, 11, 22.5, 15, 32.5,
    20, 10, 40, 20, 21, 20, 32.5, 40, 40, 5,
    25, 10, 0, 25, 10, 40, 0, 15, 10
]
media = [round(x) for x in media]
print(len(media))

llama = [
    30, 20, 20, 30, 10, 20, 20, 30, 20, 40,
    30, 30, 20, 30, 30, 30, 30, 20, 30, 30,
    30, 30, 30, 20, 30, 30, 20, 20, 10, 30,
    20, 20, 30, 20, 20, 20, 20, 30, 20, 30,
    20, 20, 30, 30, 30, 20, 20, 30, 30, 30,
    30, 30, 20, 30, 20, 20, 30, 20, 20, 30,
    30, 30, 10, 30, 30, 10, 20, 20, 10, 30,
    20, 30, 30, 30, 30, 20, 30, 20, 30, 30,
    20, 30, 30, 30, 30, 30, 30, 30, 20, 20,
    30, 20, 30, 30, 30, 20, 30, 20, 30, 20,
    30, 30, 30, 30, 30, 10, 25, 20, 30, 30,
    30, 30, 30, 20, 20, 20, 30, 30, 35, 10,
    30, 10, 10, 30, 20, 30, 20, 30, 20
]
print(len(llama))
llama = [round(x) for x in llama]

gpt35 = [
    25, 35, 20, 35, 10, 20, 30, 25, 25, 40,
    25, 40, 20, 30, 40, 40, 30, 20, 35, 30,
    35, 25, 35, 40, 40, 35, 10, 30, 15, 25,
    35, 30, 40, 30, 25, 20, 20, 35, 20, 40,
    20, 25, 30, 40, 30, 25, 25, 35, 40, 25,
    35, 40, 25, 25, 20, 25, 40, 20, 20, 30,
    35, 30, 25, 25, 40, 25, 10, 25, 10, 40,
    20, 25, 35, 35, 30, 20, 35, 20, 35, 40,
    20, 35, 25, 30, 40, 30, 25, 20, 25, 20,
    25, 20, 40, 20, 25, 15, 25, 30, 30, 30,
    30, 35, 40, 25, 35, 10, 30, 30, 30, 25,
    25, 25, 35, 30, 20, 20, 35, 40, 40, 10,
    30, 15, 25, 10, 20, 40, 20, 35, 25
]
print(len(gpt35))
gpt35 = [round(x) for x in gpt35]

gemini3 = [
    30, 25, 25, 40, 15, 20, 30, 30, 25, 40,
    25, 40, 20, 35, 40, 35, 30, 20, 35, 10,
    35, 35, 30, 30, 35, 40, 10, 25, 10, 35,
    30, 15, 40, 35, 30, 20, 10, 15, 25, 35,
    20, 25, 35, 40, 35, 15, 20, 30, 40, 30,
    40, 40, 25, 30, 20, 25, 40, 20, 20, 30,
    35, 35, 10, 20, 20, 35, 30, 35, 10, 40,
    20, 25, 40, 40, 30, 15, 40, 10, 40, 40,
    20, 40, 30, 25, 30, 40, 30, 20, 30, 20,
    30, 15, 40, 30, 20, 10, 30, 25, 40, 30,
    30, 35, 30, 30, 40, 10, 25, 30, 30, 25,
    25, 30, 30, 20, 20, 10, 30, 40, 40, 15,
    35, 15, 15, 30, 20, 40, 20, 35, 10
]
print(len(gemini3))
gemini3 = [round(x) for x in gemini3]

sabia4 = [
    35, 30, 25, 30, 25, 25, 30, 25, 30, 40,
    25, 35, 20, 30, 35, 35, 30, 25, 35, 35,
    30, 30, 35, 35, 35, 35, 25, 35, 20, 30,
    35, 25, 35, 30, 25, 20, 25, 30, 25, 35,
    25, 30, 30, 35, 30, 30, 25, 35, 35, 35,
    30, 35, 25, 30, 20, 25, 35, 35, 25, 35,
    25, 30, 25, 35, 35, 25, 25, 30, 15, 35,
    20, 35, 35, 35, 35, 25, 35, 25, 35, 35,
    15, 35, 30, 35, 35, 35, 35, 25, 30, 20,
    25, 25, 35, 25, 35, 25, 25, 30, 25, 30,
    25, 35, 25, 25, 35, 15, 30, 30, 35, 30,
    30, 25, 35, 30, 25, 25, 35, 35, 35, 25,
    30, 15, 15, 30, 25, 35, 20, 35, 25
]
print(len(sabia4))
sabia4 = [round(x) for x in sabia4]

deepseek = [
    40, 20, 20, 35, 20, 20, 40, 20, 20, 40,
    20, 35, 20, 35, 35, 40, 30, 20, 30, 20,
    35, 40, 40, 40, 35, 35, 30, 30, 20, 20,
    40, 20, 40, 30, 20, 20, 20, 30, 30, 40,
    20, 40, 40, 40, 40, 20, 20, 30, 40, 30,
    35, 40, 20, 40, 20, 20, 30, 20, 20, 40,
    30, 40, 20, 40, 30, 20, 20, 40, 20, 35,
    20, 20, 40, 35, 20, 20, 30, 20, 35, 35,
    15, 30, 35, 35, 35, 35, 40, 20, 40, 20,
    40, 20, 40, 30, 20, 20, 35, 20, 20, 40,
    35, 40, 30, 20, 40, 20, 30, 20, 30, 20,
    30, 35, 40, 20, 20, 20, 35, 40, 40, 20,
    25, 20, 20, 20, 20, 35, 20, 30, 20
]
print(len(deepseek))
deepseek = [round(x) for x in deepseek]

print("Estatísticas Automático 1_1 - +T+R")
print()
print("Avaliador1 x Avaliador2")
kappa_simples = cohen_kappa_score(avaliador1, avaliador2)
kappa_linear = cohen_kappa_score(avaliador1, avaliador2, weights='linear')
kappa_quadratico = cohen_kappa_score(avaliador1, avaliador2, weights='quadratic')
print(f"Kappa simples: {kappa_simples:.2f}")
print(f"Kappa linear: {kappa_linear:.2f}")
print(f"Kappa quadrático(QWK): {kappa_quadratico:.2f}")

B = 10000
qwk_boot = []
n = len(avaliador1)
avaliador1 = np.array(avaliador1)
avaliador2 = np.array(avaliador2)
for _ in range(B):
    idx = np.random.choice(n, n, replace=True)
    qwk = cohen_kappa_score(avaliador1[idx], avaliador2[idx], weights='quadratic')
    qwk_boot.append(qwk)

ic_inf = np.percentile(qwk_boot, 2.5)
ic_sup = np.percentile(qwk_boot, 97.5)

print(f"avaliador1 x avaliador2 QWK = {np.mean(qwk_boot):.2f}")
print(f"avaliador1 x avaliador2 IC95% = [{ic_inf:.2f}, {ic_sup:.2f}]")

print()
print("Avaliador1 x Media")
kappa_simples = cohen_kappa_score(avaliador1, media)
kappa_linear = cohen_kappa_score(avaliador1, media, weights='linear')
kappa_quadratico = cohen_kappa_score(avaliador1, media, weights='quadratic')
print(f"Kappa simples: {kappa_simples:.2f}")
print(f"Kappa linear: {kappa_linear:.2f}")
print(f"Kappa quadrático(QWK): {kappa_quadratico:.2f}")

B = 10000
qwk_boot = []
n = len(avaliador1)
avaliador1 = np.array(avaliador1)
media = np.array(media)
for _ in range(B):
    idx = np.random.choice(n, n, replace=True)
    qwk = cohen_kappa_score(avaliador1[idx], media[idx], weights='quadratic')
    qwk_boot.append(qwk)

ic_inf = np.percentile(qwk_boot, 2.5)
ic_sup = np.percentile(qwk_boot, 97.5)

print(f"avaliador1 x media QWK = {np.mean(qwk_boot):.2f}")
print(f"avaliador1 x media IC95% = [{ic_inf:.2f}, {ic_sup:.2f}]")

print()
print("Avaliador2 x Media")
kappa_simples = cohen_kappa_score(avaliador2, media)
kappa_linear = cohen_kappa_score(avaliador2, media, weights='linear')
kappa_quadratico = cohen_kappa_score(avaliador2, media, weights='quadratic')
print(f"Kappa simples: {kappa_simples:.2f}")
print(f"Kappa linear: {kappa_linear:.2f}")
print(f"Kappa quadrático(QWK): {kappa_quadratico:.2f}")

B = 10000
qwk_boot = []
n = len(avaliador2)
avaliador2 = np.array(avaliador2)
media = np.array(media)
for _ in range(B):
    idx = np.random.choice(n, n, replace=True)
    qwk = cohen_kappa_score(avaliador2[idx], media[idx], weights='quadratic')
    qwk_boot.append(qwk)

ic_inf = np.percentile(qwk_boot, 2.5)
ic_sup = np.percentile(qwk_boot, 97.5)

print(f"Avaliador2 x media QWK = {np.mean(qwk_boot):.2f}")
print(f"Avaliador2 x media IC95% = [{ic_inf:.2f}, {ic_sup:.2f}]")

print()
print("Media x Llama")
kappa_simples = cohen_kappa_score(media, llama)
kappa_linear = cohen_kappa_score(media, llama, weights='linear')
kappa_quadratico = cohen_kappa_score(media, llama, weights='quadratic')
print(f"Kappa simples: {kappa_simples:.2f}")
print(f"Kappa linear: {kappa_linear:.2f}")
print(f"Kappa quadrático(QWK): {kappa_quadratico:.2f}")


B = 10000
qwk_boot = []
n = len(media)
media = np.array(media)
llama = np.array(llama)
for _ in range(B):
    idx = np.random.choice(n, n, replace=True)
    qwk = cohen_kappa_score(media[idx], llama[idx], weights='quadratic')
    qwk_boot.append(qwk)

ic_inf = np.percentile(qwk_boot, 2.5)
ic_sup = np.percentile(qwk_boot, 97.5)

print(f"media x llama QWK = {np.mean(qwk_boot):.2f}")
print(f"media x llama IC95% = [{ic_inf:.2f}, {ic_sup:.2f}]")


print()
print("Media x Gpt35")
kappa_simples = cohen_kappa_score(media, gpt35)
kappa_linear = cohen_kappa_score(media, gpt35, weights='linear')
kappa_quadratico = cohen_kappa_score(media, gpt35, weights='quadratic')
print(f"Kappa simples: {kappa_simples:.2f}")
print(f"Kappa linear: {kappa_linear:.2f}")
print(f"Kappa quadrático(QWK): {kappa_quadratico:.2f}")

B = 10000
qwk_boot = []
n = len(media)
media = np.array(media)
gpt35 = np.array(gpt35)
for _ in range(B):
    idx = np.random.choice(n, n, replace=True)
    qwk = cohen_kappa_score(media[idx], gpt35[idx], weights='quadratic')
    qwk_boot.append(qwk)

ic_inf = np.percentile(qwk_boot, 2.5)
ic_sup = np.percentile(qwk_boot, 97.5)

print(f"media x gpt35 QWK = {np.mean(qwk_boot):.2f}")
print(f"media x gpt35 IC95% = [{ic_inf:.2f}, {ic_sup:.2f}]")

print()
print("Media x Gemini3")
kappa_simples = cohen_kappa_score(media, gemini3)
kappa_linear = cohen_kappa_score(media, gemini3, weights='linear')
kappa_quadratico = cohen_kappa_score(media, gemini3, weights='quadratic')
print(f"Kappa simples: {kappa_simples:.2f}")
print(f"Kappa linear: {kappa_linear:.2f}")
print(f"Kappa quadrático(QWK): {kappa_quadratico:.2f}")

B = 10000
qwk_boot = []
n = len(media)
media = np.array(media)
gemini3 = np.array(gemini3)
for _ in range(B):
    idx = np.random.choice(n, n, replace=True)
    qwk = cohen_kappa_score(media[idx], gemini3[idx], weights='quadratic')
    qwk_boot.append(qwk)

ic_inf = np.percentile(qwk_boot, 2.5)
ic_sup = np.percentile(qwk_boot, 97.5)

print(f"media x gemini3 QWK = {np.mean(qwk_boot):.2f}")
print(f"media x gemini3 IC95% = [{ic_inf:.2f}, {ic_sup:.2f}]")

print()
print("Media x Sabia4")
kappa_simples = cohen_kappa_score(media, sabia4)
kappa_linear = cohen_kappa_score(media, sabia4, weights='linear')
kappa_quadratico = cohen_kappa_score(media, sabia4, weights='quadratic')
print(f"Kappa simples: {kappa_simples:.2f}")
print(f"Kappa linear: {kappa_linear:.2f}")
print(f"Kappa quadrático(QWK): {kappa_quadratico:.2f}")

B = 10000
qwk_boot = []
n = len(media)
media = np.array(media)
sabia4 = np.array(sabia4)
for _ in range(B):
    idx = np.random.choice(n, n, replace=True)
    qwk = cohen_kappa_score(media[idx], sabia4[idx], weights='quadratic')
    qwk_boot.append(qwk)

ic_inf = np.percentile(qwk_boot, 2.5)
ic_sup = np.percentile(qwk_boot, 97.5)

print(f"media x sabia4 QWK = {np.mean(qwk_boot):.2f}")
print(f"media x sabia4 IC95% = [{ic_inf:.2f}, {ic_sup:.2f}]")

print()
print("Media x Deepseek")
kappa_simples = cohen_kappa_score(media, deepseek)
kappa_linear = cohen_kappa_score(media, deepseek, weights='linear')
kappa_quadratico = cohen_kappa_score(media, deepseek, weights='quadratic')
print(f"Kappa simples: {kappa_simples:.2f}")
print(f"Kappa linear: {kappa_linear:.2f}")
print(f"Kappa quadrático(QWK): {kappa_quadratico:.2f}")

B = 10000
qwk_boot = []
n = len(media)
media = np.array(media)
deepseek = np.array(deepseek)
for _ in range(B):
    idx = np.random.choice(n, n, replace=True)
    qwk = cohen_kappa_score(media[idx], deepseek[idx], weights='quadratic')
    qwk_boot.append(qwk)

ic_inf = np.percentile(qwk_boot, 2.5)
ic_sup = np.percentile(qwk_boot, 97.5)

print(f"media x deepseek QWK = {np.mean(qwk_boot):.2f}")
print(f"media x deepseek IC95% = [{ic_inf:.2f}, {ic_sup:.2f}]")
# Out:
# 129
# 129
# 129
# 129
# 129
# 129
# 129
# 129
# Estatísticas Automático 1_1 - +T+R
#
# Avaliador1 x Avaliador2
# Kappa simples: 0.47
# Kappa linear: 0.78
# Kappa quadrático(QWK): 0.91
# Avaliador1 x Avaliador2 QWK = 0.91
# Avaliador1 x Avaliador2 IC95% = [0.87, 0.94]
#
# Avaliador1 x Media
# Kappa simples: 0.50
# Kappa linear: 0.89
# Kappa quadrático(QWK): 0.97
# Avaliador1 x media QWK = 0.97
# Avaliador1 x media IC95% = [0.96, 0.98]
#
# Avaliador2 x Media
# Kappa simples: 0.51
# Kappa linear: 0.89
# Kappa quadrático(QWK): 0.98
# Avaliador2 x media QWK = 0.98
# Avaliador2 x media IC95% = [0.97, 0.98]
#
# Media x Llama
# Kappa simples: 0.01
# Kappa linear: 0.22
# Kappa quadrático(QWK): 0.37
# media x llama QWK = 0.36
# media x llama IC95% = [0.24, 0.48]
#
# Media x Gpt35
# Kappa simples: 0.06
# Kappa linear: 0.30
# Kappa quadrático(QWK): 0.46
# media x gpt35 QWK = 0.45
# media x gpt35 IC95% = [0.33, 0.56]
#
# Media x Gemini3
# Kappa simples: 0.12
# Kappa linear: 0.40
# ...

# %% [markdown]
# # Experimento 2 / +T-R

# %%
from sklearn.metrics import cohen_kappa_score

avaliador1 = [
    0, 20, 20, 40, 5, 5, 15, 25, 25, 40,
    0, 40, 0, 27, 38, 20, 10, 20, 30, 20,
    20, 40, 15, 40, 40, 20, 20, 35, 30, 20,
    10, 0, 40, 40, 40, 10, 0, 0, 15, 40,
    30, 25, 15, 30, 35, 10, 10, 30, 40, 20,
    27, 40, 25, 30, 0, 30, 40, 10, 10, 30,
    25, 40, 10, 0, 10, 20, 20, 5, 10, 20,
    0, 40, 40, 40, 0, 10, 30, 0, 30, 40,
    0.5, 40, 20, 0, 30, 40, 30, 10, 30, 12,
    20, 10, 35, 30, 20, 10, 20, 30, 40, 25,
    40, 10, 25, 35, 30, 10, 12, 25, 10, 30,
    20, 10, 40, 20, 20, 20, 25, 40, 40, 10,
    20, 10, 0, 25, 10, 40, 0, 20, 10
]
avaliador1 = [round(x) for x in avaliador1]
print(len(avaliador1))

avaliador2 = [
    0, 0, 15, 30, 10, 10, 15, 10, 25, 40,
    0, 40, 10, 25, 35, 20, 15, 0, 25, 10,
    20, 35, 20, 40, 40, 35, 25, 30, 35, 25,
    10, 0, 40, 40, 30, 10, 0, 0, 15, 40,
    20, 20, 30, 30, 35, 10, 15, 35, 35, 25,
    28, 40, 20, 30, 0, 30, 40, 10, 0, 30,
    20, 40, 25, 0, 10, 20, 30, 10, 20, 20,
    0, 40, 40, 40, 5, 10, 32, 0, 35, 40,
    0, 40, 30, 0, 30, 40, 30, 0, 30, 10,
    20, 10, 40, 30, 20, 7, 20, 40, 40, 27,
    35, 25, 25, 35, 35, 5, 10, 20, 20, 35,
    20, 10, 40, 20, 22, 20, 40, 40, 40, 0,
    30, 10, 0, 25, 10, 40, 0, 10, 10
]
avaliador2 = [round(x) for x in avaliador2]
print(len(avaliador2))

media = [
    0, 10, 17.5, 35, 7.5, 7.5, 15, 17.5, 25, 40,
    0, 40, 5, 26, 36.5, 20, 12.5, 10, 27.5, 15,
    20, 37.5, 17.5, 40, 40, 27.5, 22.5, 32.5, 32.5, 22.5,
    10, 0, 40, 40, 35, 10, 0, 0, 15, 40,
    25, 22.5, 22.5, 30, 35, 10, 12.5, 32.5, 37.5, 22.5,
    27.5, 40, 22.5, 30, 0, 30, 40, 10, 5, 30,
    22.5, 40, 17.5, 0, 10, 20, 25, 7.5, 15, 20,
    0, 40, 40, 40, 2.5, 10, 31, 0, 32.5, 40,
    0.25, 40, 25, 0, 30, 40, 30, 5, 30, 11,
    20, 10, 37.5, 30, 20, 8.5, 20, 35, 40, 26,
    37.5, 17.5, 25, 35, 32.5, 7.5, 11, 22.5, 15, 32.5,
    20, 10, 40, 20, 21, 20, 32.5, 40, 40, 5,
    25, 10, 0, 25, 10, 40, 0, 15, 10
]
media = [round(x) for x in media]
print(len(media))

llama = [
    30, 30, 20, 30, 10, 30, 30, 30, 30, 40,
    30, 30, 20, 30, 30, 30, 30, 20, 30, 30,
    30, 30, 30, 30, 30, 30, 20, 30, 10, 30,
    30, 30, 30, 30, 30, 20, 20, 30, 30, 30,
    20, 30, 30, 30, 30, 20, 30, 30, 30, 30,
    30, 30, 25, 30, 20, 20, 30, 20, 20, 30,
    35, 30, 20, 20, 30, 20, 30, 30, 10, 30,
    20, 30, 30, 30, 30, 20, 30, 20, 30, 30,
    20, 30, 30, 25, 30, 30, 30, 30, 30, 20,
    30, 20, 30, 30, 30, 20, 30, 30, 30, 20,
    30, 30, 30, 30, 30, 10, 30, 20, 30, 30,
    30, 30, 30, 20, 20, 20, 20, 30, 30, 10,
    30, 20, 10, 30, 20, 30, 20, 30, 30
]
print(len(llama))
llama = [round(x) for x in llama]

gpt35 = [
    20, 20, 20, 30, 25, 20, 25, 15, 25, 40,
    20, 40, 20, 30, 40, 35, 25, 20, 40, 25,
    20, 25, 25, 40, 30, 40, 10, 10, 10, 25,
    30, 30, 30, 30, 30, 20, 20, 20, 20, 40,
    20, 25, 30, 35, 30, 25, 20, 40, 35, 20,
    35, 40, 25, 25, 20, 25, 40, 20, 20, 30,
    25, 30, 25, 20, 25, 25, 10, 25, 10, 40,
    20, 25, 40, 30, 30, 20, 30, 20, 35, 30,
    20, 30, 25, 30, 30, 30, 30, 20, 25, 20,
    30, 25, 40, 30, 25, 15, 25, 30, 30, 30,
    25, 35, 30, 30, 40, 10, 20, 30, 25, 30,
    25, 30, 40, 25, 20, 20, 30, 40, 40, 15,
    30, 10, 15, 25, 20, 40, 20, 35, 25
]
print(len(gpt35))
gpt35 = [round(x) for x in gpt35]

gemini3 = [
    25, 20, 20, 40, 10, 20, 30, 35, 30, 40,
    20, 40, 20, 35, 40, 35, 30, 20, 30, 25,
    30, 30, 35, 40, 30, 40, 10, 10, 10, 25,
    35, 15, 35, 35, 25, 20, 20, 10, 15, 40,
    15, 30, 30, 40, 30, 15, 20, 40, 35, 25,
    40, 35, 20, 30, 20, 35, 35, 20, 20, 25,
    30, 40, 30, 20, 20, 10, 25, 35, 10, 35,
    20, 25, 35, 35, 35, 15, 40, 15, 40, 40,
    10, 40, 35, 30, 30, 35, 35, 20, 35, 20,
    30, 20, 40, 30, 15, 10, 30, 25, 35, 30,
    35, 35, 30, 30, 35, 15, 20, 10, 30, 30,
    15, 25, 30, 25, 20, 15, 30, 40, 40, 15,
    35, 10, 5, 15, 20, 35, 15, 25, 10
]
print(len(gemini3))
gemini3 = [round(x) for x in gemini3]

sabia4 = [
    35, 25, 25, 30, 25, 25, 30, 25, 35, 40,
    25, 35, 20, 35, 35, 35, 25, 25, 35, 35,
    30, 30, 35, 35, 35, 35, 25, 25, 20, 30,
    35, 25, 35, 35, 30, 20, 25, 30, 25, 35,
    25, 35, 30, 35, 25, 35, 25, 35, 35, 35,
    30, 35, 25, 35, 20, 25, 35, 35, 25, 35,
    25, 30, 30, 35, 35, 25, 25, 35, 15, 35,
    20, 30, 35, 35, 35, 25, 35, 25, 35, 35,
    15, 35, 30, 35, 30, 35, 35, 25, 35, 20,
    25, 25, 35, 25, 30, 25, 30, 25, 25, 30,
    25, 35, 25, 25, 40, 15, 25, 30, 35, 30,
    30, 25, 35, 30, 25, 20, 35, 35, 35, 25,
    30, 15, 15, 30, 25, 35, 20, 35, 25
]
print(len(sabia4))
sabia4 = [round(x) for x in sabia4]

deepseek = [
    20, 30, 20, 40, 20, 20, 35, 35, 25, 40,
    20, 40, 20, 25, 40, 40, 35, 20, 35, 25,
    40, 40, 35, 40, 30, 35, 15, 15, 20, 35,
    40, 40, 40, 30, 20, 20, 20, 20, 20, 35,
    20, 40, 20, 40, 35, 35, 20, 40, 35, 20,
    40, 40, 20, 30, 20, 20, 40, 30, 20, 20,
    30, 30, 40, 30, 40, 40, 40, 40, 20, 35,
    20, 25, 40, 40, 20, 20, 35, 20, 35, 40,
    20, 30, 30, 30, 35, 35, 35, 20, 30, 20,
    20, 20, 40, 25, 30, 35, 30, 40, 20, 30,
    30, 40, 35, 30, 30, 15, 20, 40, 40, 35,
    20, 40, 35, 30, 20, 20, 35, 40, 40, 25,
    40, 20, 35, 25, 20, 40, 20, 35, 35
]
print(len(deepseek))
deepseek = [round(x) for x in deepseek]

print("Estatísticas Automático 1_1 - +T+R")
print()
print("Avaliador1 x Avaliador2")
kappa_simples = cohen_kappa_score(avaliador1, avaliador2)
kappa_linear = cohen_kappa_score(avaliador1, avaliador2, weights='linear')
kappa_quadratico = cohen_kappa_score(avaliador1, avaliador2, weights='quadratic')
print(f"Kappa simples: {kappa_simples:.2f}")
print(f"Kappa linear: {kappa_linear:.2f}")
print(f"Kappa quadrático(QWK): {kappa_quadratico:.2f}")

B = 10000
qwk_boot = []
n = len(avaliador1)
avaliador1 = np.array(avaliador1)
avaliador2 = np.array(avaliador2)
for _ in range(B):
    idx = np.random.choice(n, n, replace=True)
    qwk = cohen_kappa_score(avaliador1[idx], avaliador2[idx], weights='quadratic')
    qwk_boot.append(qwk)

ic_inf = np.percentile(qwk_boot, 2.5)
ic_sup = np.percentile(qwk_boot, 97.5)

print(f"avaliador1 x avaliador2 QWK = {np.mean(qwk_boot):.2f}")
print(f"avaliador1 x avaliador2 IC95% = [{ic_inf:.2f}, {ic_sup:.2f}]")

print()
print("Avaliador1 x Media")
kappa_simples = cohen_kappa_score(avaliador1, media)
kappa_linear = cohen_kappa_score(avaliador1, media, weights='linear')
kappa_quadratico = cohen_kappa_score(avaliador1, media, weights='quadratic')
print(f"Kappa simples: {kappa_simples:.2f}")
print(f"Kappa linear: {kappa_linear:.2f}")
print(f"Kappa quadrático(QWK): {kappa_quadratico:.2f}")

B = 10000
qwk_boot = []
n = len(avaliador1)
avaliador1 = np.array(avaliador1)
media = np.array(media)
for _ in range(B):
    idx = np.random.choice(n, n, replace=True)
    qwk = cohen_kappa_score(avaliador1[idx], media[idx], weights='quadratic')
    qwk_boot.append(qwk)

ic_inf = np.percentile(qwk_boot, 2.5)
ic_sup = np.percentile(qwk_boot, 97.5)

print(f"avaliador1 x media QWK = {np.mean(qwk_boot):.2f}")
print(f"avaliador1 x media IC95% = [{ic_inf:.2f}, {ic_sup:.2f}]")

print()
print("Avaliador2 x Nedia")
kappa_simples = cohen_kappa_score(avaliador2, media)
kappa_linear = cohen_kappa_score(avaliador2, media, weights='linear')
kappa_quadratico = cohen_kappa_score(avaliador2, media, weights='quadratic')
print(f"Kappa simples: {kappa_simples:.2f}")
print(f"Kappa linear: {kappa_linear:.2f}")
print(f"Kappa quadrático(QWK): {kappa_quadratico:.2f}")

B = 10000
qwk_boot = []
n = len(avaliador2)
avaliador2 = np.array(avaliador2)
media = np.array(media)
for _ in range(B):
    idx = np.random.choice(n, n, replace=True)
    qwk = cohen_kappa_score(avaliador2[idx], media[idx], weights='quadratic')
    qwk_boot.append(qwk)

ic_inf = np.percentile(qwk_boot, 2.5)
ic_sup = np.percentile(qwk_boot, 97.5)

print(f"avaliador2 x media QWK = {np.mean(qwk_boot):.2f}")
print(f"avaliador2 x media IC95% = [{ic_inf:.2f}, {ic_sup:.2f}]")

print()
print("Media x Llama")
kappa_simples = cohen_kappa_score(media, llama)
kappa_linear = cohen_kappa_score(media, llama, weights='linear')
kappa_quadratico = cohen_kappa_score(media, llama, weights='quadratic')
print(f"Kappa simples: {kappa_simples:.2f}")
print(f"Kappa linear: {kappa_linear:.2f}")
print(f"Kappa quadrático(QWK): {kappa_quadratico:.2f}")

B = 10000
qwk_boot = []
n = len(media)
media = np.array(media)
llama = np.array(llama)
for _ in range(B):
    idx = np.random.choice(n, n, replace=True)
    qwk = cohen_kappa_score(media[idx], llama[idx], weights='quadratic')
    qwk_boot.append(qwk)

ic_inf = np.percentile(qwk_boot, 2.5)
ic_sup = np.percentile(qwk_boot, 97.5)

print(f"media x llama QWK = {np.mean(qwk_boot):.2f}")
print(f"media x llama IC95% = [{ic_inf:.2f}, {ic_sup:.2f}]")

print()
print("Media x Gpt35")
kappa_simples = cohen_kappa_score(media, gpt35)
kappa_linear = cohen_kappa_score(media, gpt35, weights='linear')
kappa_quadratico = cohen_kappa_score(media, gpt35, weights='quadratic')
print(f"Kappa simples: {kappa_simples:.2f}")
print(f"Kappa linear: {kappa_linear:.2f}")
print(f"Kappa quadrático(QWK): {kappa_quadratico:.2f}")

B = 10000
qwk_boot = []
n = len(media)
media = np.array(media)
gpt35 = np.array(gpt35)
for _ in range(B):
    idx = np.random.choice(n, n, replace=True)
    qwk = cohen_kappa_score(media[idx], gpt35[idx], weights='quadratic')
    qwk_boot.append(qwk)

ic_inf = np.percentile(qwk_boot, 2.5)
ic_sup = np.percentile(qwk_boot, 97.5)

print(f"media x gpt35 QWK = {np.mean(qwk_boot):.2f}")
print(f"media x gpt35 IC95% = [{ic_inf:.2f}, {ic_sup:.2f}]")

print()
print("Media x Gemini3")
kappa_simples = cohen_kappa_score(media, gemini3)
kappa_linear = cohen_kappa_score(media, gemini3, weights='linear')
kappa_quadratico = cohen_kappa_score(media, gemini3, weights='quadratic')
print(f"Kappa simples: {kappa_simples:.2f}")
print(f"Kappa linear: {kappa_linear:.2f}")
print(f"Kappa quadrático(QWK): {kappa_quadratico:.2f}")

B = 10000
qwk_boot = []
n = len(media)
media = np.array(media)
gemini3 = np.array(gemini3)
for _ in range(B):
    idx = np.random.choice(n, n, replace=True)
    qwk = cohen_kappa_score(media[idx], gemini3[idx], weights='quadratic')
    qwk_boot.append(qwk)

ic_inf = np.percentile(qwk_boot, 2.5)
ic_sup = np.percentile(qwk_boot, 97.5)

print(f"media x gemini3 QWK = {np.mean(qwk_boot):.2f}")
print(f"media x gemini3 IC95% = [{ic_inf:.2f}, {ic_sup:.2f}]")

print()
print("Media x Sabia4")
kappa_simples = cohen_kappa_score(media, sabia4)
kappa_linear = cohen_kappa_score(media, sabia4, weights='linear')
kappa_quadratico = cohen_kappa_score(media, sabia4, weights='quadratic')
print(f"Kappa simples: {kappa_simples:.2f}")
print(f"Kappa linear: {kappa_linear:.2f}")
print(f"Kappa quadrático(QWK): {kappa_quadratico:.2f}")

B = 10000
qwk_boot = []
n = len(media)
media = np.array(media)
sabia4 = np.array(sabia4)
for _ in range(B):
    idx = np.random.choice(n, n, replace=True)
    qwk = cohen_kappa_score(media[idx], sabia4[idx], weights='quadratic')
    qwk_boot.append(qwk)

ic_inf = np.percentile(qwk_boot, 2.5)
ic_sup = np.percentile(qwk_boot, 97.5)

print(f"media x sabia4 QWK = {np.mean(qwk_boot):.2f}")
print(f"media x sabia4 IC95% = [{ic_inf:.2f}, {ic_sup:.2f}]")

print()
print("Media x Deepseek")
kappa_simples = cohen_kappa_score(media, deepseek)
kappa_linear = cohen_kappa_score(media, deepseek, weights='linear')
kappa_quadratico = cohen_kappa_score(media, deepseek, weights='quadratic')
print(f"Kappa simples: {kappa_simples:.2f}")
print(f"Kappa linear: {kappa_linear:.2f}")
print(f"Kappa quadrático(QWK): {kappa_quadratico:.2f}")

B = 10000
qwk_boot = []
n = len(media)
media = np.array(media)
deepseek = np.array(deepseek)
for _ in range(B):
    idx = np.random.choice(n, n, replace=True)
    qwk = cohen_kappa_score(media[idx], deepseek[idx], weights='quadratic')
    qwk_boot.append(qwk)

ic_inf = np.percentile(qwk_boot, 2.5)
ic_sup = np.percentile(qwk_boot, 97.5)

print(f"media x deepseek QWK = {np.mean(qwk_boot):.2f}")
print(f"media x deepseek IC95% = [{ic_inf:.2f}, {ic_sup:.2f}]")
# Out:
# 129
# 129
# 129
# 129
# 129
# 129
# 129
# 129
# Estatísticas Automático 1_1 - +T+R
#
# Avaliador1 x Avaliador2
# Kappa simples: 0.47
# Kappa linear: 0.78
# Kappa quadrático(QWK): 0.91
# avaliador1 x avaliador2 QWK = 0.91
# avaliador1 x avaliador2 IC95% = [0.86, 0.94]
#
# Avaliador1 x Media
# Kappa simples: 0.50
# Kappa linear: 0.89
# Kappa quadrático(QWK): 0.97
# avaliador1 x media QWK = 0.97
# avaliador1 x media IC95% = [0.96, 0.98]
#
# Avaliador2 x Nedia
# Kappa simples: 0.51
# Kappa linear: 0.89
# Kappa quadrático(QWK): 0.98
# avaliador2 x media QWK = 0.98
# avaliador2 x media IC95% = [0.97, 0.99]
#
# Media x Llama
# Kappa simples: 0.02
# Kappa linear: 0.20
# Kappa quadrático(QWK): 0.34
# media x llama QWK = 0.33
# media x llama IC95% = [0.22, 0.44]
#
# Media x Gpt35
# Kappa simples: 0.09
# Kappa linear: 0.35
# Kappa quadrático(QWK): 0.53
# media x gpt35 QWK = 0.52
# media x gpt35 IC95% = [0.40, 0.62]
#
# Media x Gemini3
# Kappa simples: 0.05
# Kappa linear: 0.39
# ...

# %% [markdown]
# # Experimento 3 / -T+R

# %%
from sklearn.metrics import cohen_kappa_score

avaliador1 = [
    0, 20, 20, 40, 5, 5, 15, 25, 25, 40,
    0, 40, 0, 27, 38, 20, 10, 20, 30, 20,
    20, 40, 15, 40, 40, 20, 20, 35, 30, 20,
    10, 0, 40, 40, 40, 10, 0, 0, 15, 40,
    30, 25, 15, 30, 35, 10, 10, 30, 40, 20,
    27, 40, 25, 30, 0, 30, 40, 10, 10, 30,
    25, 40, 10, 0, 10, 20, 20, 5, 10, 20,
    0, 40, 40, 40, 0, 10, 30, 0, 30, 40,
    0.5, 40, 20, 0, 30, 40, 30, 10, 30, 12,
    20, 10, 35, 30, 20, 10, 20, 30, 40, 25,
    40, 10, 25, 35, 30, 10, 12, 25, 10, 30,
    20, 10, 40, 20, 20, 20, 25, 40, 40, 10,
    20, 10, 0, 25, 10, 40, 0, 20, 10
]
avaliador1 = [round(x) for x in avaliador1]
print(len(avaliador1))

avaliador2 = [
    0, 0, 15, 30, 10, 10, 15, 10, 25, 40,
    0, 40, 10, 25, 35, 20, 15, 0, 25, 10,
    20, 35, 20, 40, 40, 35, 25, 30, 35, 25,
    10, 0, 40, 40, 30, 10, 0, 0, 15, 40,
    20, 20, 30, 30, 35, 10, 15, 35, 35, 25,
    28, 40, 20, 30, 0, 30, 40, 10, 0, 30,
    20, 40, 25, 0, 10, 20, 30, 10, 20, 20,
    0, 40, 40, 40, 5, 10, 32, 0, 35, 40,
    0, 40, 30, 0, 30, 40, 30, 0, 30, 10,
    20, 10, 40, 30, 20, 7, 20, 40, 40, 27,
    35, 25, 25, 35, 35, 5, 10, 20, 20, 35,
    20, 10, 40, 20, 22, 20, 40, 40, 40, 0,
    30, 10, 0, 25, 10, 40, 0, 10, 10
]
avaliador2 = [round(x) for x in avaliador2]
print(len(avaliador2))

media = [
    0, 10, 17.5, 35, 7.5, 7.5, 15, 17.5, 25, 40,
    0, 40, 5, 26, 36.5, 20, 12.5, 10, 27.5, 15,
    20, 37.5, 17.5, 40, 40, 27.5, 22.5, 32.5, 32.5, 22.5,
    10, 0, 40, 40, 35, 10, 0, 0, 15, 40,
    25, 22.5, 22.5, 30, 35, 10, 12.5, 32.5, 37.5, 22.5,
    27.5, 40, 22.5, 30, 0, 30, 40, 10, 5, 30,
    22.5, 40, 17.5, 0, 10, 20, 25, 7.5, 15, 20,
    0, 40, 40, 40, 2.5, 10, 31, 0, 32.5, 40,
    0.25, 40, 25, 0, 30, 40, 30, 5, 30, 11,
    20, 10, 37.5, 30, 20, 8.5, 20, 35, 40, 26,
    37.5, 17.5, 25, 35, 32.5, 7.5, 11, 22.5, 15, 32.5,
    20, 10, 40, 20, 21, 20, 32.5, 40, 40, 5,
    25, 10, 0, 25, 10, 40, 0, 15, 10
]
media = [round(x) for x in media]
print(len(media))

llama = [
    20, 20, 20, 30, 10, 20, 20, 20, 20, 30,
    20, 30, 20, 20, 30, 30, 20, 20, 30, 20,
    20, 30, 20, 30, 30, 30, 10, 20, 10, 20,
    30, 20, 30, 30, 30, 20, 20, 20, 20, 30,
    20, 30, 30, 30, 30, 10, 20, 30, 30, 30,
    30, 30, 20, 30, 20, 20, 30, 30, 20, 20,
    30, 30, 10, 20, 20, 10, 30, 10, 10, 30,
    20, 20, 30, 30, 20, 10, 30, 20, 30, 30,
    20, 30, 30, 20, 30, 30, 35, 20, 30, 20,
    20, 20, 30, 20, 20, 30, 20, 20, 10, 10,
    30, 30, 30, 30, 30, 10, 20, 10, 30, 20,
    20, 20, 30, 20, 20, 20, 30, 30, 30, 10,
    20, 20, 30, 30, 20, 40, 20, 30, 20
]
print(len(llama))
llama = [round(x) for x in llama]

gpt35 = [
    25, 10, 20, 40, 25, 20, 30, 25, 15, 40,
    25, 40, 20, 35, 40, 30, 25, 20, 30, 40,
    20, 30, 35, 30, 35, 30, 10, 30, 10, 30,
    25, 25, 40, 35, 30, 20, 20, 25, 20, 30,
    20, 30, 35, 40, 35, 30, 25, 35, 40, 35,
    40, 40, 20, 30, 20, 25, 40, 30, 20, 35,
    30, 25, 25, 25, 30, 25, 25, 15, 15, 40,
    20, 30, 30, 35, 25, 10, 35, 20, 35, 40,
    20, 35, 25, 30, 35, 30, 15, 20, 25, 20,
    30, 25, 40, 20, 20, 25, 25, 25, 30, 30,
    40, 40, 40, 30, 35, 10, 25, 40, 30, 25,
    20, 25, 25, 20, 20, 20, 40, 40, 40, 15,
    40, 20, 30, 40, 20, 30, 20, 30, 30
]
print(len(gpt35))
gpt35 = [round(x) for x in gpt35]

gemini3 = [
    10, 30, 20, 40, 10, 20, 30, 10, 10, 40,
    25, 35, 10, 30, 40, 30, 25, 10, 10, 10,
    30, 35, 35, 35, 10, 35, 10, 10, 10, 30,
    35, 10, 40, 35, 10, 20, 10, 10, 20, 40,
    10, 10, 30, 40, 35, 10, 35, 35, 10, 35,
    40, 40, 15, 15, 10, 10, 40, 10, 10, 35,
    35, 30, 10, 20, 20, 10, 10, 15, 10, 35,
    20, 10, 30, 30, 15, 10, 40, 10, 40, 40,
    20, 35, 35, 30, 10, 10, 10, 20, 10, 20,
    30, 15, 10, 15, 10, 40, 30, 20, 10, 30,
    10, 35, 35, 10, 40, 10, 35, 10, 30, 15,
    25, 10, 30, 10, 20, 20, 10, 40, 40, 10,
    35, 10, 10, 10, 20, 35, 10, 30, 10
]
print(len(gemini3))
gemini3 = [round(x) for x in gemini3]

sabia4 = [
    25, 25, 15, 35, 15, 25, 25, 25, 25, 35,
    25, 30, 10, 25, 35, 30, 25, 15, 30, 30,
    25, 30, 25, 30, 30, 30, 15, 25, 15, 25,
    30, 25, 35, 25, 25, 15, 15, 25, 25, 30,
    15, 25, 30, 35, 30, 15, 20, 25, 35, 35,
    30, 35, 20, 25, 10, 25, 35, 30, 25, 25,
    30, 25, 15, 15, 30, 25, 15, 25, 25, 35,
    10, 30, 35, 30, 25, 15, 30, 15, 35, 35,
    15, 35, 25, 25, 25, 35, 25, 20, 25, 15,
    25, 25, 25, 25, 25, 25, 25, 25, 25, 30,
    30, 30, 30, 25, 35, 15, 25, 30, 30, 25,
    25, 15, 35, 25, 20, 30, 30, 35, 35, 25,
    25, 15, 25, 25, 15, 35, 10, 25, 25
]
print(len(sabia4))
sabia4 = [round(x) for x in sabia4]

deepseek = [
    20, 30, 20, 40, 20, 20, 35, 35, 25, 40,
    20, 40, 20, 25, 40, 40, 35, 20, 35, 25,
    40, 40, 35, 40, 30, 35, 15, 15, 20, 35,
    40, 40, 40, 30, 20, 20, 20, 20, 20, 35,
    20, 40, 20, 40, 35, 35, 20, 40, 35, 20,
    40, 40, 20, 30, 20, 20, 40, 30, 20, 20,
    30, 30, 40, 30, 40, 40, 40, 40, 20, 35,
    20, 25, 40, 40, 20, 20, 35, 20, 35, 40,
    20, 30, 30, 30, 35, 35, 35, 20, 30, 20,
    20, 20, 40, 25, 30, 35, 30, 40, 20, 30,
    30, 40, 35, 30, 30, 15, 20, 40, 40, 35,
    20, 40, 35, 30, 20, 20, 35, 40, 40, 25,
    40, 20, 35, 25, 20, 40, 20, 35, 35
]
print(len(deepseek))
deepseek = [round(x) for x in deepseek]

print("Estatísticas Automático 1_1 - +T+R")
print()
print("Avaliador1 x Avaliador2")
kappa_simples = cohen_kappa_score(avaliador1, avaliador2)
kappa_linear = cohen_kappa_score(avaliador1, avaliador2, weights='linear')
kappa_quadratico = cohen_kappa_score(avaliador1, avaliador2, weights='quadratic')
print(f"Kappa simples: {kappa_simples:.2f}")
print(f"Kappa linear: {kappa_linear:.2f}")
print(f"Kappa quadrático(QWK): {kappa_quadratico:.2f}")

B = 10000
qwk_boot = []
n = len(avaliador1)
avaliador1 = np.array(avaliador1)
avaliador2 = np.array(avaliador2)
for _ in range(B):
    idx = np.random.choice(n, n, replace=True)
    qwk = cohen_kappa_score(avaliador1[idx], avaliador2[idx], weights='quadratic')
    qwk_boot.append(qwk)

ic_inf = np.percentile(qwk_boot, 2.5)
ic_sup = np.percentile(qwk_boot, 97.5)

print(f"avaliador1 x avaliador2 QWK = {np.mean(qwk_boot):.2f}")
print(f"avaliador1 x avaliador2 IC95% = [{ic_inf:.2f}, {ic_sup:.2f}]")

print()
print("Avaliador1 x Media")
kappa_simples = cohen_kappa_score(avaliador1, media)
kappa_linear = cohen_kappa_score(avaliador1, media, weights='linear')
kappa_quadratico = cohen_kappa_score(avaliador1, media, weights='quadratic')
print(f"Kappa simples: {kappa_simples:.2f}")
print(f"Kappa linear: {kappa_linear:.2f}")
print(f"Kappa quadrático(QWK): {kappa_quadratico:.2f}")

B = 10000
qwk_boot = []
n = len(avaliador1)
avaliador1 = np.array(avaliador1)
media = np.array(media)
for _ in range(B):
    idx = np.random.choice(n, n, replace=True)
    qwk = cohen_kappa_score(avaliador1[idx], media[idx], weights='quadratic')
    qwk_boot.append(qwk)

ic_inf = np.percentile(qwk_boot, 2.5)
ic_sup = np.percentile(qwk_boot, 97.5)

print(f"avaliador1 x media QWK = {np.mean(qwk_boot):.2f}")
print(f"avaliador1 x media IC95% = [{ic_inf:.2f}, {ic_sup:.2f}]")

print()
print("Avaliador2 x Media")
kappa_simples = cohen_kappa_score(avaliador2, media)
kappa_linear = cohen_kappa_score(avaliador2, media, weights='linear')
kappa_quadratico = cohen_kappa_score(avaliador2, media, weights='quadratic')
print(f"Kappa simples: {kappa_simples:.2f}")
print(f"Kappa linear: {kappa_linear:.2f}")
print(f"Kappa quadrático(QWK): {kappa_quadratico:.2f}")

B = 10000
qwk_boot = []
n = len(avaliador2)
avaliador2 = np.array(avaliador1)
media = np.array(media)
for _ in range(B):
    idx = np.random.choice(n, n, replace=True)
    qwk = cohen_kappa_score(avaliador2[idx], media[idx], weights='quadratic')
    qwk_boot.append(qwk)

ic_inf = np.percentile(qwk_boot, 2.5)
ic_sup = np.percentile(qwk_boot, 97.5)

print(f"avaliador2 x media QWK = {np.mean(qwk_boot):.2f}")
print(f"avaliador2 x media IC95% = [{ic_inf:.2f}, {ic_sup:.2f}]")

print()
print("Media x Llama")
kappa_simples = cohen_kappa_score(media, llama)
kappa_linear = cohen_kappa_score(media, llama, weights='linear')
kappa_quadratico = cohen_kappa_score(media, llama, weights='quadratic')
print(f"Kappa simples: {kappa_simples:.2f}")
print(f"Kappa linear: {kappa_linear:.2f}")
print(f"Kappa quadrático(QWK): {kappa_quadratico:.2f}")

B = 10000
qwk_boot = []
n = len(media)
media = np.array(media)
llama = np.array(llama)
for _ in range(B):
    idx = np.random.choice(n, n, replace=True)
    qwk = cohen_kappa_score(media[idx], llama[idx], weights='quadratic')
    qwk_boot.append(qwk)

ic_inf = np.percentile(qwk_boot, 2.5)
ic_sup = np.percentile(qwk_boot, 97.5)

print(f"media x llama QWK = {np.mean(qwk_boot):.2f}")
print(f"media x llama IC95% = [{ic_inf:.2f}, {ic_sup:.2f}]")

print()
print("Media x Gpt35")
kappa_simples = cohen_kappa_score(media, gpt35)
kappa_linear = cohen_kappa_score(media, gpt35, weights='linear')
kappa_quadratico = cohen_kappa_score(media, gpt35, weights='quadratic')
print(f"Kappa simples: {kappa_simples:.2f}")
print(f"Kappa linear: {kappa_linear:.2f}")
print(f"Kappa quadrático(QWK): {kappa_quadratico:.2f}")

B = 10000
qwk_boot = []
n = len(media)
media = np.array(media)
gpt35 = np.array(gpt35)
for _ in range(B):
    idx = np.random.choice(n, n, replace=True)
    qwk = cohen_kappa_score(media[idx], gpt35[idx], weights='quadratic')
    qwk_boot.append(qwk)

ic_inf = np.percentile(qwk_boot, 2.5)
ic_sup = np.percentile(qwk_boot, 97.5)

print(f"media x gpt35 QWK = {np.mean(qwk_boot):.2f}")
print(f"media x gpt35 IC95% = [{ic_inf:.2f}, {ic_sup:.2f}]")

print()
print("Media x Gemini3")
kappa_simples = cohen_kappa_score(media, gemini3)
kappa_linear = cohen_kappa_score(media, gemini3, weights='linear')
kappa_quadratico = cohen_kappa_score(media, gemini3, weights='quadratic')
print(f"Kappa simples: {kappa_simples:.2f}")
print(f"Kappa linear: {kappa_linear:.2f}")
print(f"Kappa quadrático(QWK): {kappa_quadratico:.2f}")

B = 10000
qwk_boot = []
n = len(media)
media = np.array(media)
gemini3 = np.array(gemini3)
for _ in range(B):
    idx = np.random.choice(n, n, replace=True)
    qwk = cohen_kappa_score(media[idx], gemini3[idx], weights='quadratic')
    qwk_boot.append(qwk)

ic_inf = np.percentile(qwk_boot, 2.5)
ic_sup = np.percentile(qwk_boot, 97.5)

print(f"media x gemini3 QWK = {np.mean(qwk_boot):.2f}")
print(f"media x gemini3 IC95% = [{ic_inf:.2f}, {ic_sup:.2f}]")

print()
print("Media x Sabia4")
kappa_simples = cohen_kappa_score(media, sabia4)
kappa_linear = cohen_kappa_score(media, sabia4, weights='linear')
kappa_quadratico = cohen_kappa_score(media, sabia4, weights='quadratic')
print(f"Kappa simples: {kappa_simples:.2f}")
print(f"Kappa linear: {kappa_linear:.2f}")
print(f"Kappa quadrático(QWK): {kappa_quadratico:.2f}")

B = 10000
qwk_boot = []
n = len(media)
media = np.array(media)
sabia4 = np.array(sabia4)
for _ in range(B):
    idx = np.random.choice(n, n, replace=True)
    qwk = cohen_kappa_score(media[idx], sabia4[idx], weights='quadratic')
    qwk_boot.append(qwk)

ic_inf = np.percentile(qwk_boot, 2.5)
ic_sup = np.percentile(qwk_boot, 97.5)

print(f"media x sabia4 QWK = {np.mean(qwk_boot):.2f}")
print(f"media x sabia4 IC95% = [{ic_inf:.2f}, {ic_sup:.2f}]")

print()
print("Media x Deepseek")
kappa_simples = cohen_kappa_score(media, deepseek)
kappa_linear = cohen_kappa_score(media, deepseek, weights='linear')
kappa_quadratico = cohen_kappa_score(media, deepseek, weights='quadratic')
print(f"Kappa simples: {kappa_simples:.2f}")
print(f"Kappa linear: {kappa_linear:.2f}")
print(f"Kappa quadrático(QWK): {kappa_quadratico:.2f}")

B = 10000
qwk_boot = []
n = len(media)
media = np.array(media)
deepseek = np.array(deepseek)
for _ in range(B):
    idx = np.random.choice(n, n, replace=True)
    qwk = cohen_kappa_score(media[idx], deepseek[idx], weights='quadratic')
    qwk_boot.append(qwk)

ic_inf = np.percentile(qwk_boot, 2.5)
ic_sup = np.percentile(qwk_boot, 97.5)

print(f"media x deepseek QWK = {np.mean(qwk_boot):.2f}")
print(f"media x deepseek IC95% = [{ic_inf:.2f}, {ic_sup:.2f}]")
# Out:
# 129
# 129
# 129
# 129
# 129
# 129
# 129
# 129
# Estatísticas Automático 1_1 - +T+R
#
# Avaliador1 x Avaliador2
# Kappa simples: 0.47
# Kappa linear: 0.78
# Kappa quadrático(QWK): 0.91
# avaliador1 x avaliador2 QWK = 0.91
# avaliador1 x avaliador2 IC95% = [0.87, 0.94]
#
# Avaliador1 x Media
# Kappa simples: 0.50
# Kappa linear: 0.89
# Kappa quadrático(QWK): 0.97
# avaliador1 x media QWK = 0.97
# avaliador1 x media IC95% = [0.96, 0.98]
#
# Avaliador2 x Media
# Kappa simples: 0.51
# Kappa linear: 0.89
# Kappa quadrático(QWK): 0.98
# avaliador2 x media QWK = 0.97
# avaliador2 x media IC95% = [0.96, 0.98]
#
# Media x Llama
# Kappa simples: 0.04
# Kappa linear: 0.28
# Kappa quadrático(QWK): 0.46
# media x llama QWK = 0.46
# media x llama IC95% = [0.34, 0.56]
#
# Media x Gpt35
# Kappa simples: 0.08
# Kappa linear: 0.29
# Kappa quadrático(QWK): 0.47
# media x gpt35 QWK = 0.46
# media x gpt35 IC95% = [0.35, 0.55]
#
# Media x Gemini3
# Kappa simples: 0.05
# Kappa linear: 0.23
# ...
